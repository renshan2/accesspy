# %% [markdown]
# #%245
# Neural Network

# %%
import tensorflow as tf 
print(tf.version)
# Out:
# <module 'tensorflow_core._api.v2.version' from 'C:\\Users\\RenShan\\Anaconda3\\lib\\site-packages\\tensorflow_core\\_api\\v2\\version\\__init__.py'>

# %% [markdown]
# Tensorflow Neural Network Layers:
# Input Layer
# Hidden Layer
#
# Loss Function:
# Mean Squared Error
# Mean Absolute Error
# Hinge Loss

# %% [markdown]
# Gradient Descent is the algorithm used to find the optimal paramaters (weights and biases) for our network, while backpropagation is the process of calculating the gradient that is used in the gradient descent step.

# %%
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist # load datasets
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data() # split into train and test datasets

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images[0,23,23] #look at one pixel, it could be from 0 - 255
# Out:
# 194

# %%
train_labels[:10]
# Out:
# array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5], dtype=uint8)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(train_images[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# scale the image from 0 - 255 to 0 - 1
train_images = train_images / 255.0   
test_images = test_images / 255.0

# %%
# build the model
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)), # input layer (1)
    keras.layers.Dense(128, activation = 'relu'),  # hidden layer (2)
    keras.layers.Dense(10, activation = 'softmax')  # output layer (3)
])

# %%
# compile the model
model.compile(optimizer = 'adam', 
                loss = 'sparse_categorical_crossentropy',
                metrics = ['accuracy'])

# %%
model.fit(train_images, train_labels, epochs = 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.4976 - accuracy: 0.8253
# Epoch 2/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.3734 - accuracy: 0.8659
# Epoch 3/10
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.3372 - accuracy: 0.8758
# Epoch 4/10
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.3136 - accuracy: 0.8850
# Epoch 5/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.2965 - accuracy: 0.8916
# Epoch 6/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.2830 - accuracy: 0.8952
# Epoch 7/10
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.2702 - accuracy: 0.8991
# Epoch 8/10
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.2578 - accuracy: 0.9036
# Epoch 9/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose = 1)
# Out:
# 10000/10000 [==============================] - 0s 43us/sample - loss: 0.3494 - accuracy: 0.8742

# %%
print('Test accuracy', test_acc)
# Out:
# Test accuracy 0.8742

# %%
predictions = model.predict(test_images)
print(class_names[np.argmax(predictions[0])])
# Out:
# Ankle boot

# %%
plt.figure()
plt.imshow(test_images[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# 3:41:35 Verifying Predictions
