# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#plt.rcParams['finger.figsize'] = (20.0, 10.0)

#reading data
df = pd.read_csv('headbrain.csv')
print(data.shape)
df.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
# Collectying X and Y
X = df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

# mean of x and y
mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of values
m = len(X)

# usingthe formula to calculate b1 and b2
numer = 0
denom = 0
for i in range(m):
    numer += (X[i]-mean_x)*(Y[i]-mean_y)
    denom += (X[i]- mean_y) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)
print(b1, b0)
# Out:
# 0.006182615188584821 1260.4058463001695

# %%
# plotting values and regression line

max_x = np.max(X) + 100
min_x = np.min(X) - 100

# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# plotting line
plt.plot(x, y, color='#48b970', label='Regression Line')
# plotting Scatter Points
plt.scatter(X, Y, c='#ef5423', label = 'Scatter Plot')

plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()
