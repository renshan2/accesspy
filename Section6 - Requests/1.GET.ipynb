# %% [markdown]
# install http requests

# %%
# !pip install requests --upgrade
# Out:
# Requirement already up-to-date: requests in c:\users\renshan\anaconda3\lib\site-packages (2.22.0)
# ...

# %%
# !mkdir newfolder

# %%
import requests
from pprint import pprint
import json

# %% [markdown]
# dounder -> "__"

# %%
print(requests.__version__)
# Out:
# 2.22.0

# %%
print(requests.__copyright__)
# Out:
# Copyright 2019 Kenneth Reitz

# %%
r_get = requests.get("https://www.metaweather.com/api/location/2487956/2018/11/28/")

# %%
r_get.status_code
# Out:
# 200

# %%
### http request return codes
Informational responses (100–199)   
Successful responses (200–299)  
Redirects (300–399)  
Client errors (400–499)  
and Server errors (500–599)

# %%
type(r_get)
# Out:
# requests.models.Response

# %%
pprint(r_get.headers)
# Out:
# {'x-xss-protection': '1; mode=block', 'Content-Language': 'en', 'x-content-type-options': 'nosniff', 'strict-transport-security': 'max-age=2592000; includeSubDomains', 'Vary': 'Accept-Language, Cookie', 'Allow': 'GET, HEAD, OPTIONS', 'x-frame-options': 'DENY', 'Content-Type': 'application/json', 'X-Cloud-Trace-Context': '4240748d9153c4274e579d8f9d23ec82', 'Date': 'Sun, 22 Dec 2019 18:28:25 GMT', 'Server': 'Google Frontend', 'Content-Length': '28697'}

# %% [markdown]
# 'Allow':'GET, HEAD, OPTIONS'

# %%
r_get
# Out:
# <Response [200]>

# %%
data = json.loads(r_get.text)
pprint(data)
# Out:
# [{'air_pressure': 1008.13,
#   'applicable_date': '2018-11-28',
#   'created': '2018-11-29T05:56:17.059738Z',
#   'humidity': 89,
#   'id': 5885499629633536,
#   'max_temp': 16.335,
#   'min_temp': 12.97,
#   'predictability': 77,
#   'the_temp': 15.06,
#   'visibility': 7.489076294440467,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 200.97477009137089,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 6.86569258669172},
#  {'air_pressure': 1008.13,
#   'applicable_date': '2018-11-28',
#   'created': '2018-11-29T02:56:17.135964Z',
#   'humidity': 90,
#   'id': 6735400240414720,
#   'max_temp': 16.1425,
#   'min_temp': 12.9525,
#   'predictability': 77,
#   'the_temp': 15.035,
#   'visibility': 7.7388675137198755,
#   'weather_state_abbr': 'hr',
#   'weather_state_name': 'Heavy Rain',
#   'wind_direction': 201.26605567730294,
#   'wind_direction_compass': 'SSW',
#   'wind_speed': 7.336546311691721},
#  {'air_pressure': 1014.63,
# ...

# %%
r_get.is_redirect
# Out:
# False

# %% [markdown]
# https://swapi.co
# use default
# planets/3

# %%
r_get = requests.get('http://swapi.co/api/planets/3')

# %%
r_get.status_code

# %%
pprint(r_get.headers)

# %%
r_get.text

# %% [markdown]
# including parameters in a GET request

# %% [markdown]
# A basic POST request

# %% [markdown]
# A POST request with Multiple Parameters

# %% [markdown]
# The HEAD Request

# %%
if r_get.status_code == 200:
# Out:
# True
